# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting gdeltdoc==1.4.0
#   Downloading gdeltdoc-1.4.0-py3-none-any.whl (12 kB)
# Collecting networkx==3.0
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.5 MB/s eta 0:00:00
# Collecting nxviz==0.7.4
#   Downloading nxviz-0.7.4-py3-none-any.whl (28 kB)
# Collecting netgraph==4.11.7
#   Downloading netgraph-4.11.7-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 KB 7.3 MB/s eta 0:00:00
# Collecting dataframe_image==0.1.5
#   Downloading dataframe_image-0.1.5-py3-none-any.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 55.3 MB/s eta 0:00:00
# Collecting easynmt==2.0.2
#   Downloading EasyNMT-2.0.2.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.25.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: pandas>=1.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: numpy>=1.19.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nxviz==0.7.4->-r ./requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: matplotlib>=3.3.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nxviz==0.7.4->-r ./requirements.txt (line 3)) (3.6.0)
# Collecting more-itertools>=8.6.0
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nxviz==0.7.4->-r ./requirements.txt (line 3)) (0.12.1)
# Collecting palettable>=3.3.0
#   Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 KB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from netgraph==4.11.7->-r ./requirements.txt (line 4)) (1.9.3)
# Collecting rectangle-packer
#   Downloading rectangle_packer-2.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 7.8 MB/s eta 0:00:00
# Collecting grandalf
#   Downloading grandalf-0.8-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: nbconvert>=5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (6.4.5)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: mistune in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (3.8.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from easynmt==2.0.2->-r ./requirements.txt (line 6)) (4.64.1)
# Collecting transformers<5,>=4.4
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from easynmt==2.0.2->-r ./requirements.txt (line 6)) (1.12.1)
# Requirement already satisfied: nltk in /shared-libs/python3.9/py/lib/python3.9/site-packages (from easynmt==2.0.2->-r ./requirements.txt (line 6)) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.0 MB/s eta 0:00:00
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: protobuf in /shared-libs/python3.9/py/lib/python3.9/site-packages (from easynmt==2.0.2->-r ./requirements.txt (line 6)) (3.19.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (4.37.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: traitlets>=5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (5.5.0)
# Requirement already satisfied: jinja2>=2.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: nbformat>=4.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (5.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: testpath in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (4.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.4)
# Requirement already satisfied: pygments>=2.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (2.13.0)
# Requirement already satisfied: bleach in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.1.4->gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.25.1->gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.25.1->gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.25.1->gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.25.1->gdeltdoc==1.4.0->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from torch>=1.6.0->easynmt==2.0.2->-r ./requirements.txt (line 6)) (4.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers<5,>=4.4->easynmt==2.0.2->-r ./requirements.txt (line 6)) (2022.9.13)
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from transformers<5,>=4.4->easynmt==2.0.2->-r ./requirements.txt (line 6)) (3.8.0)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.4 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.8 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/pyyaml/
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 KB 16.8 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.14.1
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 KB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (2.3.2.post1)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /root/venv/lib/python3.9/site-packages (from fasttext->easynmt==2.0.2->-r ./requirements.txt (line 6)) (58.1.0)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->easynmt==2.0.2->-r ./requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk->easynmt==2.0.2->-r ./requirements.txt (line 6)) (8.1.3)
# Collecting fsspec
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 KB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client>=6.1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (7.4.3)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (1.5.6)
# Requirement already satisfied: jsonschema>=2.6 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (2.16.2)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->nxviz==0.7.4->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: tornado>=6.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (6.2)
# Requirement already satisfied: pyzmq>=23.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image==0.1.5->-r ./requirements.txt (line 5)) (24.0.1)
# Building wheels for collected packages: easynmt, fasttext
#   Building wheel for easynmt (setup.py): started
#   Building wheel for easynmt (setup.py): finished with status 'done'
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19918 sha256=280a914051d68154d3b3f38caaaa75a946ce6d1736cea9ecae9fd45624fbfd2b
#   Stored in directory: /root/.cache/pip/wheels/26/53/00/5761f3b9bf6af87bdbc440292a4eb98a6afb25823dd76fca26
#   Building wheel for fasttext (setup.py): started
#   Building wheel for fasttext (setup.py): still running...
#   Building wheel for fasttext (setup.py): finished with status 'done'
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp39-cp39-linux_x86_64.whl size=4640479 sha256=15ca74fabacd9ccf88d1c54d652a85b9e7306b414b4869f200d789c4fe6027c9
#   Stored in directory: /root/.cache/pip/wheels/64/57/bc/1741406019061d5664914b070bd3e71f6244648732bc96109e
# Successfully built easynmt fasttext
# Installing collected packages: tokenizers, sentencepiece, safetensors, rectangle-packer, pyyaml, pybind11, palettable, networkx, more-itertools, grandalf, fsspec, huggingface-hub, fasttext, transformers, netgraph, gdeltdoc, nxviz, easynmt, dataframe_image
# Successfully installed dataframe_image-0.1.5 easynmt-2.0.2 fasttext-0.9.2 fsspec-2023.6.0 gdeltdoc-1.4.0 grandalf-0.8 huggingface-hub-0.16.4 more-itertools-9.1.0 netgraph-4.11.7 networkx-3.0 nxviz-0.7.4 palettable-3.3.3 pybind11-2.11.1 pyyaml-6.0.1 rectangle-packer-2.0.1 safetensors-0.3.1 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.31.0
# WARNING: You are using pip version 22.0.4; however, version 23.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0d79deab-c9c6-414b-8803-1e385542ff1f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
